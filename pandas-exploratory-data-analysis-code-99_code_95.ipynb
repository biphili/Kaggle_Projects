# %% [markdown]
# # During the lockdown I published my first book titled Inspiration:Thoughts on Spirituality,Technology,Wealth,Leadership and Motivation.The preview of the book can be read from the Amazon link https://lnkd.in/gj7bMQA .
# # E Book is availabe for Rs 99 in India.Paperback Edition of the book is available on Amazon.com link https://lnkd.in/gkFYYMJ

# %% [markdown]
# In this notebook we will be exploring the data using pandas.We will try to demonstrate the power of pandas.You can explore by other notebooks,kernels and codes from the link https://www.kaggle.com/biphili/code

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nba17-18/nba_extra.csv
# /kaggle/input/nba17-18/nba.csv
# /kaggle/input/vince-carter/Vince_carter.jpg

# %% [markdown]
# ### Importing Data

# %%
df = pd.read_csv("../input/nba17-18/nba.csv")
df.head()
# Out:
#    Rk                   Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   1   Alex Abrines\abrinal01  SG   24  OKC  75  1134   9.0  0.567  0.759
# 1   2       Quincy Acy\acyqu01  PF   27  BRK  70  1359   8.2  0.525  0.800
# 2   3   Steven Adams\adamsst01   C   24  OKC  76  2487  20.6  0.630  0.003
# 3   4    Bam Adebayo\adebaba01   C   20  MIA  69  1368  15.7  0.570  0.021
# 4   5  Arron Afflalo\afflaar01  SG   32  ORL  53   682   5.8  0.516  0.432
#
#    ...  Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0  ...          NaN  1.3  1.0  2.2  0.094          NaN  -0.5  -1.7 -2.2  -0.1
# 1  ...          NaN -0.1  1.1  1.0  0.036          NaN  -2.0  -0.2 -2.2  -0.1
# 2  ...          NaN  6.7  3.0  9.7  0.187          NaN   2.2   1.1  3.3   3.3
# 3  ...          NaN  2.3  1.9  4.2  0.148          NaN  -1.6   1.8  0.2   0.8
# 4  ...          NaN -0.1  0.2  0.1  0.009          NaN  -4.1  -1.8 -5.8  -0.7
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Displaying Columns

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'Unnamed: 19', 'OWS', 'DWS', 'WS', 'WS/48', 'Unnamed: 24', 'OBPM',
#        'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %% [markdown]
# ### Acronms
#
# Rk    - Rank                                   TRB -Total Rebounds Per Game
#
# Pos   - Position                               AST -Assists Per Game
#
# Age   - Age                                    ORB -Offensive Rebounds Per Game
#
# Tm    - Team                                   DRB -Defensive Rebounds Per Game
#
# G     - Games                                  AST -Assists Per Game
#
# MP    - Minutes Played Per Game                BLK -Blocks Per Game
#
# TOV   - Turnover Per Game                      STL -Steals Per Game
#
# PER   -The player efficiency rating (PER) is a rating of a player's per-minute productivity.
#
# 3PAr  -is a measure of what % of a player's shots come from long-distance, another good gauge of how they're utilized offensively.

# %% [markdown]
# ### Shape

# %%
df.shape
# Out:
# (664, 29)

# %% [markdown]
# ### Missing Values

# %%
df.isnull().sum()
# Out:
# Rk               0
# Player           0
# Pos              0
# Age              0
# Tm               0
# G                0
# MP               0
# PER              0
# TS%              4
# 3PAr             4
# FTr              4
# ORB%             0
# DRB%             0
# TRB%             0
# AST%             0
# STL%             0
# BLK%             0
# TOV%             4
# USG%             0
# Unnamed: 19    664
# OWS              0
# DWS              0
# WS               0
# WS/48            0
# Unnamed: 24    664
# OBPM             0
# DBPM             0
# BPM              0
# VORP             0
# dtype: int64

# %% [markdown]
# ### Replace Missing Values with Zeros

# %%
df1 = df.fillna(0)

# %%
df1.isnull().sum()
# Out:
# Rk             0
# Player         0
# Pos            0
# Age            0
# Tm             0
# G              0
# MP             0
# PER            0
# TS%            0
# 3PAr           0
# FTr            0
# ORB%           0
# DRB%           0
# TRB%           0
# AST%           0
# STL%           0
# BLK%           0
# TOV%           0
# USG%           0
# Unnamed: 19    0
# OWS            0
# DWS            0
# WS             0
# WS/48          0
# Unnamed: 24    0
# OBPM           0
# DBPM           0
# BPM            0
# VORP           0
# dtype: int64

# %% [markdown]
# ### Dropping Column

# %%
df1 = df1.drop(['Unnamed: 19','Unnamed: 24'],axis=1)
df1.head()
# Out:
#    Rk                   Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0   1   Alex Abrines\abrinal01  SG   24  OKC  75  1134   9.0  0.567  0.759
# 1   2       Quincy Acy\acyqu01  PF   27  BRK  70  1359   8.2  0.525  0.800
# 2   3   Steven Adams\adamsst01   C   24  OKC  76  2487  20.6  0.630  0.003
# 3   4    Bam Adebayo\adebaba01   C   20  MIA  69  1368  15.7  0.570  0.021
# 4   5  Arron Afflalo\afflaar01  SG   32  ORL  53   682   5.8  0.516  0.432
#
#    ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...   7.4  12.7  1.3  1.0  2.2  0.094  -0.5  -1.7 -2.2  -0.1
# 1  ...  13.3  14.4 -0.1  1.1  1.0  0.036  -2.0  -0.2 -2.2  -0.1
# 2  ...  13.2  16.7  6.7  3.0  9.7  0.187   2.2   1.1  3.3   3.3
# 3  ...  13.6  15.9  2.3  1.9  4.2  0.148  -1.6   1.8  0.2   0.8
# 4  ...  10.8  12.5 -0.1  0.2  0.1  0.009  -4.1  -1.8 -5.8  -0.7
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Writing to CSV File

# %%
df1.to_csv('nba18.csv',index=False)

# %%
ls
# Out:
# __notebook__.ipynb  nba18.csv

# %% [markdown]
# ### Displaying Rows of Data

# %%
pd.set_option('display.max_rows',5)
df
# Out:
#       Rk                  Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0      1  Alex Abrines\abrinal01  SG   24  OKC  75  1134   9.0  0.567  0.759
# 1      2      Quincy Acy\acyqu01  PF   27  BRK  70  1359   8.2  0.525  0.800
# ..   ...                     ...  ..  ...  ...  ..   ...   ...    ...    ...
# 662  539    Ante Zizic\zizican01   C   21  CLE  32   214  24.2  0.746  0.000
# 663  540   Ivica Zubac\zubaciv01   C   20  LAL  43   410  15.3  0.557  0.008
#
#      ...  Unnamed: 19  OWS  DWS   WS  WS/48  Unnamed: 24  OBPM  DBPM  BPM  \
# 0    ...          NaN  1.3  1.0  2.2  0.094          NaN  -0.5  -1.7 -2.2
# 1    ...          NaN -0.1  1.1  1.0  0.036          NaN  -2.0  -0.2 -2.2
# ..   ...          ...  ...  ...  ...    ...          ...   ...   ...  ...
# 662  ...          NaN  0.9  0.2  1.0  0.231          NaN   1.3  -1.2  0.1
# 663  ...          NaN  0.5  0.5  1.0  0.118          NaN  -2.7   0.5 -2.2
#
#      VORP
# 0    -0.1
# 1    -0.1
# ..    ...
# 662   0.1
# ...

# %% [markdown]
# We have displayed 5 rows from the dataset.We can change the display by changing the number of rows in the code.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Reverting Back to Normal Display

# %%
pd.set_option('display.max_rows',10)
df1
# Out:
#       Rk                   Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 0      1   Alex Abrines\abrinal01  SG   24  OKC  75  1134   9.0  0.567  0.759
# 1      2       Quincy Acy\acyqu01  PF   27  BRK  70  1359   8.2  0.525  0.800
# 2      3   Steven Adams\adamsst01   C   24  OKC  76  2487  20.6  0.630  0.003
# 3      4    Bam Adebayo\adebaba01   C   20  MIA  69  1368  15.7  0.570  0.021
# 4      5  Arron Afflalo\afflaar01  SG   32  ORL  53   682   5.8  0.516  0.432
# ..   ...                      ...  ..  ...  ...  ..   ...   ...    ...    ...
# 659  537   Tyler Zeller\zellety01   C   28  BRK  42   703  15.3  0.587  0.114
# 660  537   Tyler Zeller\zellety01   C   28  MIL  24   406  17.1  0.622  0.019
# 661  538    Paul Zipser\zipsepa01  SF   23  CHI  54   824   5.2  0.445  0.470
# 662  539     Ante Zizic\zizican01   C   21  CLE  32   214  24.2  0.746  0.000
# 663  540    Ivica Zubac\zubaciv01   C   20  LAL  43   410  15.3  0.557  0.008
#
# ...

# %% [markdown]
# ### Datatypes in the dataframe

# %%
df1.dtypes
# Out:
# Rk          int64
# Player     object
# Pos        object
# Age         int64
# Tm         object
#            ...
# WS/48     float64
# OBPM      float64
# DBPM      float64
# BPM       float64
# VORP      float64
# Length: 27, dtype: object

# %% [markdown]
# ### Showing Numerical Data types in Dataframe

# %%
df1.select_dtypes(include=['number'])
# Out:
#       Rk  Age   G    MP   PER    TS%   3PAr    FTr  ORB%  DRB%  ...  TOV%  \
# 0      1   24  75  1134   9.0  0.567  0.759  0.158   2.5   8.9  ...   7.4
# 1      2   27  70  1359   8.2  0.525  0.800  0.164   3.1  17.0  ...  13.3
# 2      3   24  76  2487  20.6  0.630  0.003  0.402  16.6  13.9  ...  13.2
# 3      4   20  69  1368  15.7  0.570  0.021  0.526   9.7  21.6  ...  13.6
# 4      5   32  53   682   5.8  0.516  0.432  0.160   0.6  10.1  ...  10.8
# ..   ...  ...  ..   ...   ...    ...    ...    ...   ...   ...  ...   ...
# 659  537   28  42   703  15.3  0.587  0.114  0.262   9.4  20.0  ...  12.1
# 660  537   28  24   406  17.1  0.622  0.019  0.181  13.6  18.4  ...   9.6
# 661  538   23  54   824   5.2  0.445  0.470  0.107   1.6  16.0  ...  14.9
# 662  539   21  32   214  24.2  0.746  0.000  0.433  12.8  18.6  ...  12.1
# 663  540   20  43   410  15.3  0.557  0.008  0.418  11.8  20.1  ...  15.3
#
#      USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# ...

# %% [markdown]
# ### Showing Categorical Data Types in DataFrame

# %%
df1.select_dtypes(include=['object'])
# Out:
#                       Player Pos   Tm
# 0     Alex Abrines\abrinal01  SG  OKC
# 1         Quincy Acy\acyqu01  PF  BRK
# 2     Steven Adams\adamsst01   C  OKC
# 3      Bam Adebayo\adebaba01   C  MIA
# 4    Arron Afflalo\afflaar01  SG  ORL
# ..                       ...  ..  ...
# 659   Tyler Zeller\zellety01   C  BRK
# 660   Tyler Zeller\zellety01   C  MIL
# 661    Paul Zipser\zipsepa01  SF  CHI
# 662     Ante Zizic\zizican01   C  CLE
# 663    Ivica Zubac\zubaciv01   C  LAL
#
# [664 rows x 3 columns]

# %% [markdown]
# # Questions

# %% [markdown]
# ### What is the age of the oldest player?

# %%
df1[df1.Age == df1.Age.max()]
# Out:
#      Rk                  Player Pos  Age   Tm   G    MP   PER    TS%   3PAr  \
# 105  87  Vince Carter\cartevi01  SF   41  SAC  58  1026  10.8  0.523  0.583
#
#      ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 105  ...  10.7  14.7  0.3  0.9  1.2  0.056  -1.5   0.4 -1.1   0.2
#
# [1 rows x 27 columns]

# %%
PlayerMaxAge =df1[df1.Age == df1.Age.max()]

# %% [markdown]
# ### Name of the Oldest Player

# %%
PlayerMaxAge.Player
# Out:
# 105    Vince Carter\cartevi01
# Name: Player, dtype: object

# %%
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import numpy as np
img=np.array(Image.open('../input//vince-carter/Vince_carter.jpg'))
fig=plt.figure(figsize=(10,10))
plt.imshow(img,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Vincent Lamar Carter Jr. Carter was an eight-time All-Star in the NBA and a two-time All-NBA Team selection. He is the only player in NBA history to play 22 seasons and in four different decades from his debut in 1999 to his retirement in 2020.

# %% [markdown]
# ### Which Postion Vincent Lamar Plays?

# %%
PlayerMaxAge.Pos
# Out:
# 105    SF
# Name: Pos, dtype: object

# %% [markdown]
# The small forward (SF), also known as the three, is one of the five positions in a regulation basketball game. Small forwards are typically shorter, quicker, and leaner than power forwards and centers but taller, larger, and stronger than either of the guard positions.

# %% [markdown]
# ### How many Games Did Vincent Lamar Play?

# %%
PlayerMaxAge.G
# Out:
# 105    58
# Name: G, dtype: int64

# %% [markdown]
# ### Which players have highest assist?

# %%
df1[df1['AST%'] == df1['AST%'].max()]
# Out:
#       Rk                       Player Pos  Age   Tm   G    MP   PER    TS%  \
# 625  508  Russell Westbrook\westbru01  PG   29  OKC  80  2914  24.7  0.524
#
#       3PAr  ...  TOV%  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
# 625  0.193  ...  16.4  34.1  5.5  4.5  10.1  0.166   5.1   3.1  8.2   7.5
#
# [1 rows x 27 columns]

# %% [markdown]
# ### Which players has played for more time (minutess) for Oklahoma City Thunder Basketball Team?

# %%
OKC = df1.groupby('Tm').get_group('OKC')

# %%
OKC[OKC.MP == OKC.MP.max()]
# Out:
#       Rk                       Player Pos  Age   Tm   G    MP   PER    TS%  \
# 625  508  Russell Westbrook\westbru01  PG   29  OKC  80  2914  24.7  0.524
#
#       3PAr  ...  TOV%  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP
# 625  0.193  ...  16.4  34.1  5.5  4.5  10.1  0.166   5.1   3.1  8.2   7.5
#
# [1 rows x 27 columns]

# %% [markdown]
# We can see that Russell Westbrook has played the longest time for team OKC.

# %% [markdown]
# ### Off the five Positions which position has most assists?

# %%
df1.groupby('Pos')['AST%'].describe()
# Out:
#        count       mean       std   min     25%    50%     75%   max
# Pos
# C      126.0   9.344444  5.267737   0.0   6.500   8.45  11.450  29.6
# PF     122.0   9.062295  6.816537   0.0   5.375   8.05  10.950  44.4
# PG     142.0  22.649296  9.574603   0.0  16.100  22.45  29.150  49.8
# PG-SG    1.0  26.700000       NaN  26.7  26.700  26.70  26.700  26.7
# SF     115.0   8.362609  5.967595   0.0   5.150   7.20  10.100  41.7
# SF-SG    2.0   6.600000  1.272792   5.7   6.150   6.60   7.050   7.5
# SG     156.0  12.125000  7.970167   0.0   7.800  10.40  15.575  45.1

# %% [markdown]
# We can see some position has a combination of two positions.For our analysis we will be taking five positions which are solo positions.

# %%
positions = ['C','PF','SF','PG','SG']
POS = df1[df1['Pos'].isin(positions)]
#POS

# %%
POS.groupby('Pos')['AST%'].describe()
# Out:
#      count       mean       std  min     25%    50%     75%   max
# Pos
# C    126.0   9.344444  5.267737  0.0   6.500   8.45  11.450  29.6
# PF   122.0   9.062295  6.816537  0.0   5.375   8.05  10.950  44.4
# PG   142.0  22.649296  9.574603  0.0  16.100  22.45  29.150  49.8
# SF   115.0   8.362609  5.967595  0.0   5.150   7.20  10.100  41.7
# SG   156.0  12.125000  7.970167  0.0   7.800  10.40  15.575  45.1

# %% [markdown]
# The point guard (PG), known as the one, is typically the team's best ball handler and passer. They usually are very fast and are good at driving and short-range. Therefore, they often lead their team in assists and are able to create shots for themselves and their teammates.

# %% [markdown]
# ### Histograms

# %%
AST = df1[['Pos','AST%']]

positions = ['C','PF','SF','PG','SG']
AST = AST[AST['Pos'].isin(positions)]
#AST

# %% [markdown]
# ### Pandas Built in Vizualization

# %%
AST['AST%'].hist(by=AST['Pos'])
plt.show()

# %% [markdown]
# ### Changing Plot Layout

# %%
AST['AST%'].hist(by=AST['Pos'],layout=(1,5))
plt.show()

# %% [markdown]
# ### Changing Plot Size

# %%
AST['AST%'].hist(by=AST['Pos'],layout=(1,5),figsize=(16,2))
plt.show()

# %% [markdown]
# ### Box Plots

# %%
AST.boxplot(column='AST%',by='Pos')
plt.show()

# %% [markdown]
# As we saw earlier the Point Gauard (PG) position has more assists.

# %% [markdown]
# ### Seaborn Data Visualisation

# %%
import seaborn as sns
sns.boxplot(x='Pos',y='AST%',data=AST)
plt.show()

# %% [markdown]
# Seaborn gives a better visualisation than matplotlib.

# %% [markdown]
# ### Box Plot with Jitters

# %%
sns.boxplot(x='Pos',y='AST%',data=AST)
sns.stripplot(x='Pos',y='AST%',data=AST,
             jitter=True,
             marker='o',
             alpha=0.8,
             color='black')
plt.show()

# %% [markdown]
# We have overlapped the actual distribution of the data on the boxplot.

# %% [markdown]
# ### Heat Map

# %%
corr = df1.corr()
#corr

# %%
sns.heatmap(corr)
plt.show()

# %% [markdown]
# ### Adjusting Size of Heatmap

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr,square=True)
plt.show()

# %% [markdown]
# We can see that correlation values above and below the diagonal are the same.We can mask half of the heatmap for better interpretation of results.

# %% [markdown]
# ### Masking Half of the Heat Map

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f,ax = plt.subplots(figsize=(10,10))
    ax = sns.heatmap(corr,mask=mask,vmax=1,square=True)
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
number = df1.select_dtypes(include=['number'])
#number.iloc[:,:5]

# %% [markdown]
# ### Selecting Five Specific Columns

# %%
selections = ['Age','G','MP','PER','AST%']
df5 = df1[selections]
#df5

# %%
g = sns.PairGrid(df5)
g.map(plt.scatter);

# %% [markdown]
# In the scatter plot we can look at the correlation between the features.

# %%
g = sns.PairGrid(number)
g.map(plt.scatter);

# %% [markdown]
# ### Displaying Entire Rows

# %%
pd.set_option('display.max_rows',df1.shape[0]+1)
df1
# Out:
#       Rk                              Player    Pos  Age   Tm   G    MP  \
# 0      1              Alex Abrines\abrinal01     SG   24  OKC  75  1134
# 1      2                  Quincy Acy\acyqu01     PF   27  BRK  70  1359
# 2      3              Steven Adams\adamsst01      C   24  OKC  76  2487
# 3      4               Bam Adebayo\adebaba01      C   20  MIA  69  1368
# 4      5             Arron Afflalo\afflaar01     SG   32  ORL  53   682
# 5      6              Cole Aldrich\aldrico01      C   29  MIN  21    49
# 6      7         LaMarcus Aldridge\aldrila01      C   32  SAS  75  2509
# 7      8             Jarrett Allen\allenja01      C   19  BRK  72  1441
# 8      9              Kadeem Allen\allenka01     PG   25  BOS  18   107
# 9     10                Tony Allen\allento01     SF   36  NOP  22   273
# 10    11           Al-Farouq Aminu\aminual01     PF   27  POR  69  2072
# 11    12           Justin Anderson\anderju01     SF   24  PHI  38   519
# ...

# %% [markdown]
# # TO BE CONTINUED
